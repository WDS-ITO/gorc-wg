# %% [markdown]
# # Types of commons

# %% [markdown]
# #### This notebook holds the converted data for representing types of commons that have participated in the GORC-WG speaker series or otherwise investigated in support of creating GORC-WG outputs.
# #### Find the reasoning behind this chart and explanations for the visual representation in the GORC-WG martyr doc: https://docs.google.com/document/d/1c34WsuG2tm_dFIWhqgwHKM8T3L1ws2t4cceClRxWrO0/edit?usp=sharing

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
# horizontal axis = maturity (young =1)
# vertical axis = weight class (lightweight = 1)
# colours = reach (red=domain, green = national, blue = pan-national --> orange=domain+national, purple=domain+pannational)
# shapes = service level (square=dispersed, triangle=collected, circle=centralised)

legend_elements=[Line2D([0],[0],c='white', markerfacecolor='black',markersize=10,marker='s',label='Dispersed Services'),
                 Line2D([0],[0],c='white', markerfacecolor='black',markersize=10, marker='^',label='Collected Services'),
                 Line2D([0],[0],c='white', markerfacecolor='black',markersize=10,marker='o',label='Centralized Services'),
                Line2D([0],[0],c='blue',lw=4,label='Pan-national'),
                 Line2D([0],[0],c='purple',lw=4,label='Domain-specific and Pan-national'),
                 Line2D([0],[0],c='red',lw=4,label='Domain-specific'),
                 Line2D([0],[0],c='orange',lw=4,label='Domain-specific and National'),
                 Line2D([0],[0],c='green',lw=4,label='National')]

fig=plt.figure()
ax=fig.add_subplot(111)
plt.scatter([3], [1], marker='s', c='purple', s=200, label="IVOA")
ax.text(2.925,1.1,'IVOA',None)
plt.scatter([1], [2], marker='o', c='green', s=200, label='NII RCOS')
ax.text(0.925,1.8,'NII RCOS',None)
plt.scatter([1.95], [3], marker='^', c='blue', s=200, label="EOSC")
ax.text(1.8,2.8,'EOSC',None)
plt.scatter([2], [2], marker='^', c='green',s=200, label="ARDC")
ax.text(1.9,2.1,'ARDC',None)
plt.scatter([1.1], [2], marker='^', c='green',s=200, label="KISTI KRDC")
ax.text(1.025,2.1,'KISTI KRDC',None)
plt.scatter([1], [1], marker='^', c='orange',s=200, label="CCADI")
ax.text(0.925,1.1,'CCADI',None)
plt.scatter([1],[1.7], marker='^', c='green',s=200,label="MOSP")
ax.text(1.075, 1.65,'MOSP', None)
plt.scatter([2.05],[3], marker='^', c='green',s=200,label="Alliance")
ax.text(2.025, 2.8,'Alliance', None)
plt.scatter([3],[3], marker='^', c='green',s=200,label="IBICT")
ax.text(2.9, 2.8,'IBICT', None)
plt.scatter([3],[2], marker='s', c='blue',s=200,label="NeIC")
ax.text(2.925, 1.8,'NeIC', None)
plt.scatter([2.1],[2], marker='o', c='green',s=200,label="CSTCloud")
ax.text(2.075, 1.8,'CSTCloud', None)
plt.scatter([1],[3], marker='^', c='blue',s=200,label="AOSP")
ax.text(0.95, 2.8,'AOSP', None)
plt.xticks([1,2,3])
plt.yticks([1,2,3])
ax.set_ylabel('Weight Class')
ax.set_xlabel('Maturity')
lgd=ax.legend(handles=legend_elements, bbox_to_anchor=(1,.8))

plt.show()
#plt.savefig('TypesofCommons.png', bbox_inches='tight')

# %%
import plotly.graph_objects as go
import numpy as np

x=np.array([3,1,2,2,1,1,.9,1.9,3,3,2,1]) #Maturity
y=np.array([1,2,3,2,2,1,2,3,3,2,2,3]) #weight class
z=np.array([1,3,2,2,2,2,2,2,2,1,3,2]) # service level
c=np.array(['purple','green','blue','green','green','orange','green','green','green','blue','green','blue']) #reach
a = np.array(['circle', 'circle','circle','circle','circle', 'circle','diamond','circle', 'circle', 'circle', 
              'circle', 'diamond']) # approach (community-first or combo community and infrastructure)
s = np.array([17,17,17,17,17,17,14,17,17,17,17,14])
commons=np.array(['IVOA', 'NII RCOS', 'EOSC','ARDC','KISTI KRDC','CCADI','MOSP','Alliance','IBICT','NeIC','CSTCloud','AOSP'])

fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, text=commons, 
                                   hovertemplate = '<b>%{text}</b><br><br>'+
                                   'Maturity: %{x}<br>'+'Weight Class: %{y}<br>'+'Service Level: %{z}'+'<extra></extra>',
                                   showlegend=False,
                                   mode='markers',
                                  marker=dict(
        size=s, #change marker size depending on marker shape
        color=c,                # set color to an array/list of desired values
        opacity=0.8,
        symbol=a #set shape to approach value
    ))])

fig.update_layout(title={
    'text':'Commons reviewed by GORC-WG',
    'y':0.9,
    'x':0.35,
    'xanchor':'center',
    'yanchor':'top'})

fig.update_layout(scene = dict(
                    xaxis_title='Maturity',
                    yaxis_title='Weight Class',
                    zaxis_title='Service Level'),
                    width=800,
                  height=800,
                    margin=dict(r=20, b=10, l=20, t=20))

fig.update_layout(scene=dict( xaxis = dict(
                        ticktext= ['Young','Middle Aged','Mature'],
                        tickvals= [1,2,3],
                        tickangle=-90,
                        range=[0.75,3.25]),
                    yaxis = dict(
                        ticktext= ['Lightweight','Middleweight','Heavyweight'],
                        tickvals= [1,2,3],
                        tickangle=-90,
                        range=[0.75,3.25]),
                    zaxis = dict(
                        ticktext= ['Dispersed','Collected','Centralized'],
                        tickvals= [1,2,3],
                        tickangle=-90,
                        range=[0.75,3.25])))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='blue'),
    name="Pan-National"
))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='purple'),
    name="Domain-specific & Pan-National"
))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='red'),
    name="Domain-specific"
))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='orange'),
    name="Domain-specific & National"
))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='green'),
    name="National"
))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='black',symbol='circle-open'),
    name="Community+Infrastructure approach"
))

fig.add_trace(go.Scatter3d(
    x=[0],
    y=[0],
    z=[0],
    mode='markers',
    marker=dict(color='black',symbol='diamond-open'),
    name="Community-first approach"
))

fig.write_html("index.html")
#fig.show()

# %% [markdown]
# ## Sandbox

# %%
#TEST of plotly using example from https://plotly.com/python/3d-scatter-plots/#basic-3d-scatter-plot, adding write_html function.
import plotly.graph_objects as go
import numpy as np

# Helix equation
t = np.linspace(0, 10, 50)
x, y, z = np.cos(t), np.sin(t), t

fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z,
                                   mode='markers')])
fig.write_html("index.html")
fig.show()

# %%
# %matplotlib widget
from mpl_toolkits.mplot3d import Axes3D

legend_elements2=[Line2D([0],[0],c='blue',lw=4,label='Pan-national'),
                 Line2D([0],[0],c='purple',lw=4,label='Domain-specific & Pan-national'),
                 Line2D([0],[0],c='red',lw=4,label='Domain-specific'),
                 Line2D([0],[0],c='orange',lw=4,label='Domain-specific & National'),
                 Line2D([0],[0],c='green',lw=4,label='National')]
fig = plt.figure()
ax1 = fig.add_subplot(projection='3d')
ax1.scatter([3], [1],[1], marker='o', c='purple', s=200, label="IVOA")
ax1.text(3.1,1.1,1.1,'IVOA, (3,1,1)',None)
ax1.scatter([1], [2], [3], marker='o', c='green', s=200, label='NII RCOS')
ax1.text(1.1,2.1,3.1,'NII RCOS, (1,2,3)',None)
ax1.scatter([2], [3], [2], marker='o', c='blue', s=200, label="EOSC")
ax1.text(2.1,3.1,2.1,'EOSC, (2,3,2)',None)
ax1.scatter([2], [2], [2], marker='o', c='green', s=200, label="ARDC")
ax1.text(2.1,2.1,2.1,'ARDC, (2,2,2)',None)
ax1.scatter([1], [2], [2], marker='o', c='green', s=200, label="KISTI KRDC")
ax1.text(1.1,2.1,2.1,'KISTI KRDC, (1,2,2)',None)
ax1.scatter([1], [1], [2], marker='o', c='orange', s=200, label="CCADI")
ax1.text(1.1,1.1,2.1,'CCADI, (1,1,2)',None)
ax1.set_title("Commons Types ")
ax1.set_xlabel('Maturity')
ax1.set_ylabel('Weight Class')
ax1.set_zlabel('Service Level')
ax1.set_xticks([1,2,3])
ax1.set_yticks([1,2,3])
ax1.set_zticks([1,2,3])

ax1.legend(handles=legend_elements2, bbox_to_anchor=(1,.6,.45,.5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
